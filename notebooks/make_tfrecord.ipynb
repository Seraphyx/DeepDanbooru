# %% [markdown]
# # Make into TFRecord

# %%
import os
import csv
import json
from pprint import pprint
import collections
import numpy as np
import pandas as pd
import tensorflow as tf
import glob
import pickle

data_dir = os.path.join("..", "data")
# danbooru_img_dir = os.path.join(data_dir, "danbooru", "38986_61452_upload_danbooru-images", "danbooru-images", "0059")
danbooru_meta_dir = os.path.join(data_dir, "danbooru", "danbooru2019", "metadata")
danbooru_project_name = "project-small"

# Tfrecord
tfrecord_dir = os.path.join(data_dir, "preprocessed", danbooru_project_name)

# Metadata
output_metadata_dir = os.path.join(data_dir, "preprocessed", danbooru_project_name)
output_metadata_filename = "metadata.pkl"
output_metadata_path = os.path.join(output_metadata_dir, output_metadata_filename)
print(output_metadata_path)


# Make project name subfolder
if not os.path.exists(tfrecord_dir):
    print("Making folder: {}".format(tfrecord_dir))
    os.makedirs(tfrecord_dir)
# Out:
# ..\data\preprocessed\project-small\metadata.pkl

# %%
# %%time


def read_metadata(file_path, top_n=None):
    lines = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        line = file.readline()
        while line:
            line = json.loads(file.readline())
            lines[line['id']] = line
    return lines

            
def read_metadata_dict(file_path, top_n=None, filter_attributes=None, filter_tag=None):
    data = dict()
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            l = json.loads(line)
            if filter_attributes:
                l = {k: l.get(k, None) for k in filter_attributes}
                l['tags'] = [t['name'] for t in l['tags']]
                
            
            if filter_tag:
                if len([l for l in l['tags'] if l in filter_tag]):
                    data[l['id']] = l
            else:
                data[l['id']] = l
    return data

def read_metadata_list(file_path, top_n=None, filter_attributes=None, filter_tag=None):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            l = json.loads(line)
            if filter_attributes:
                l = {k: l.get(k, None) for k in filter_attributes}
                l['tags'] = [t['name'] for t in l['tags']]
                       
            if filter_tag:
                if len([l for l in l['tags'] if l in filter_tag]):
                    data.append(l)
            else:
                data.append(l)
    return data

def read_metadata_dir(file_dir, filter_attributes=None, filter_tag=None):
    # Walk through each
    json_path_list = [os.path.join(root, file) for root, subdirs, files in os.walk(file_dir) for file in files]
    json_dict = dict()
    for json_i, json_path in enumerate(json_path_list):
        print("Loading: {} of {}".format(str(json_i + 1).zfill(3), str(len(json_path_list)).zfill(3)))
        json_dict.update(read_metadata_dict(json_path, filter_attributes=filter_attributes, filter_tag=filter_tag))
        
    return json_dict
        
    

# data_meta_raw = read_metadata_list(danbooru_meta_path, filter_attributes=['id', 'file_ext', 'tags'], filter_tag=["transparent_background"])
# data_meta = read_metadata_list(danbooru_meta_path, filter_attributes=['id', 'file_ext', 'tags'], filter_tag=["transparent_background", ""])
# data_meta = read_metadata_dict(danbooru_meta_path, filter_attributes=['id', 'file_ext', 'tags'])

single_filter_tag = "dragon_ball"
# data_meta = read_metadata_dir(danbooru_meta_dir, filter_attributes=['id', 'file_ext', 'tags', 'is_rating_locked'], filter_tag=[single_filter_tag])
# Out:
# Wall time: 0 ns

# %%
# Read
with open(output_metadata_path, 'rb') as f:
    data_meta = pickle.load(f)

# Get tags from each image
tag_list = [tag for k, v in data_meta.items() for tag in v['tags']]

# Count each tags
tag_counts = collections.Counter(tag_list)

print("There are n = {} labels".format(len(tag_counts)))
tag_all_array = np.array(list(tag_counts))

tag_map = dict(zip(tag_all_array, list(range(len(tag_all_array)))))
# Out:
# There are n = 15096 labels

# %% [markdown]
# # Image List

# %%
image_dir = os.path.join(data_dir, "danbooru", "danbooru2019", "original")
print(image_dir)
print(os.path.join(image_dir, "*"))


image_list = []
accepted_file_ext = ['jpg', 'jpeg', 'png']
for file_ext in accepted_file_ext:
    image_list.extend(glob.glob(os.path.join(image_dir, "*", "*.{file_ext}".format(file_ext=file_ext))))
    
print(len(image_list))
pprint(image_list[:10])
# Out:
# ..\data\danbooru\danbooru2019\original
# ..\data\danbooru\danbooru2019\original\*
# 8055
# ['..\\data\\danbooru\\danbooru2019\\original\\0000\\162000.jpg',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\2066000.jpg',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\2767000.png',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\2881000.jpg',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\2963000.jpg',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\3191000.jpg',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\3253000.png',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\3436000.png',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\3493000.png',
#  '..\\data\\danbooru\\danbooru2019\\original\\0000\\3605000.png']

# %% [markdown]
# # TFRecord

# %%
import pathlib
import contextlib2

class DataUtil(object):
    def __init__(self):
        pass

    def int64_feature(self, value):
      return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))


    def int64_list_feature(self, value):
      return tf.train.Feature(int64_list=tf.train.Int64List(value=value))


    def bytes_feature(self, value):
      return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))


    def bytes_list_feature(self, value):
      return tf.train.Feature(bytes_list=tf.train.BytesList(value=value))


    def float_list_feature(self, value):
      return tf.train.Feature(float_list=tf.train.FloatList(value=value))


def open_sharded_output_tfrecords(exit_stack, base_path, num_shards, extension="tfrecord"):
    """Opens all TFRecord shards for writing and adds them to an exit stack.
    Args:
    exit_stack: A context2.ExitStack used to automatically closed the TFRecords
      opened in this function.
    base_path: The base path for all shards
    num_shards: The number of shards
    Returns:
    The list of opened TFRecords. Position k in the list corresponds to shard k.
    """
    tf_record_output_filenames = [
        '{}-{:05d}-of-{:05d}.{}'.format(base_path, idx, num_shards, extension)
        for idx in range(num_shards)
    ]

    tfrecords = [
        exit_stack.enter_context(tf.io.TFRecordWriter(file_name))
        for file_name in tf_record_output_filenames
    ]

    return tfrecords


# Reads an image from a file, decodes it into a dense tensor, and resizes it
# to a fixed shape.
def parse_image(img_path, height=512, width=512, resize=True):
    
    filename = os.path.basename(img_path)
    img_id, img_ext = os.path.splitext(filename)
    
    parts = tf.strings.split(img_path, os.sep)

    image = tf.io.read_file(img_path)
    if img_ext in [".jpg", ".jpeg"]:
        image = tf.image.decode_jpeg(image, channels=3)
    if img_ext in [".png"]:
        image = tf.image.decode_png(image, channels=3, dtype=tf.dtypes.uint8)
#     image = tf.image.resize(image, [height, width], preserve_aspect_ratio=True)
    if resize:
        image = tf.image.convert_image_dtype(image, tf.float32)
        image = tf.image.resize_with_pad(image=image, target_height=height, target_width=width)
    image = tf.image.convert_image_dtype(image, tf.uint8)
    return image


def create_dataset(img, img_path, labels_text, label_id, file_ext):
    
    if tf.is_tensor(img):
        img = img.numpy()
        
    # Flatten
    img_flat = img.astype(dtype=np.uint8).flatten()
        
    labels_text = [tag.encode("utf8") for tag in labels_text]
    
    image_shape = img.shape

    feature_dict = {
        'image/height': dataset_util.int64_feature(image_shape[0]),
        'image/width': dataset_util.int64_feature(image_shape[1]),
        'image/depth': dataset_util.int64_feature(image_shape[2]),
        'image/object/class/text': dataset_util.bytes_list_feature(labels_text),
        'image/object/class/label': dataset_util.int64_list_feature(label_id),
        'image/encoded': dataset_util.int64_list_feature(img_flat.tolist()),
#         'image/encoded': dataset_util.bytes_list_feature(img_flat.encode('utf8')),
#         'image/encoded': dataset_util.bytes_feature(img.tobytes()),
        'image/filename': dataset_util.bytes_feature(img_path.encode('utf8')),
        'image/format': dataset_util.bytes_feature(file_ext.encode('utf8')),
    }

    example = tf.train.Example(features=tf.train.Features(feature=feature_dict))

    return example


dataset_util = DataUtil()

# %%
# TFRecord
def image_to_tfrecord_shards(image_path_list, data_meta, tag_map, tfrecord_dir, tfrecord_prefix, n_shards=8):
    
    tfrecord_output_path = os.path.join(tfrecord_dir, tfrecord_prefix)
    data_info_json_path = os.path.join(tfrecord_dir, "data_info.json")

    img_counter = 0
    
    print_per_n = 10
    
    tag_list = []
    
    # Start shards
    with contextlib2.ExitStack() as tf_record_close_stack:
        print("image_path_list n = {}".format(len(image_path_list)))
        
        # List of shards
        output_tfrecords = open_sharded_output_tfrecords(
            tf_record_close_stack, tfrecord_output_path, n_shards)
        
        # Loop through image
        for img_i, img_path in enumerate(image_path_list):
            
            # img path
            img_filename = os.path.basename(img_path)
            img_id, img_ext = os.path.splitext(img_filename)

            # If not found in metadata continue
            if img_id not in data_meta.keys():
                print("img_id = {} not in data_met".format(img_id))
                continue
            
            if img_counter % print_per_n == 0:
                print("Working on image i = {}".format(img_counter))
            # Get information
            img_meta = data_meta[img_id]
            
            if img_meta is None:
                print("img_id = {} does not exist in img_meta".format(img_id))
                continue

            # Parse Image
            try:
                img = parse_image(img_path, resize=True)
            except:
                print("img_id = {} failed to load image {}".format(img_id, img_path))
                continue
                
                
            try:
                tags = img_meta['tags']
            except:
                print("img_id = {} tags does not exist in img_meta".format(img_id))
                print(img_meta)
                print(img_id)
                break
                
            try:
                tags = img_meta['tags']
            except:
                print("img_id = {} tags does not exist in img_meta".format(img_id))
                print(img_meta)
                break
                
            try:
                file_ext = img_meta['file_ext']
            except:
                print("img_id = {} file_ext does not exist in img_meta".format(img_id))
                print(img_meta)
                break
                
            try:
                file_ext = img_meta['file_ext']
            except:
                print("img_id = {} file_ext does not exist in img_meta".format(img_id))
                print(img_meta)
                break
                
            try:
                label_id = [tag_map[tag] for tag in tags]
            except:
                print("img_id = {} label_id error".format(img_id))
                print(img_meta)
                break
                
            

            # Tags
            tag_list.extend(tags)
                
            # Make an example
            example = create_dataset(
                img=img, 
                img_path=img_path, 
                labels_text=tags, 
                label_id=label_id, 
                file_ext=file_ext)

            # Write tfrecord to shard
            shard_idx = img_counter % tfrecord_n_shards
            output_tfrecords[shard_idx].write(example.SerializeToString())
            img_counter += 1
        print("Made tfrecord with n = {}".format(img_counter))

    # Dataset Info
    tag_counts = dict(collections.Counter(tag_list))
    n_classes = len(tag_counts)
    tag_map = dict(zip(list(tag_counts), list(range(n_classes))))
    data_info = {
        'tag_counts': tag_counts,
        'n_classes': n_classes,
        'tag_map': tag_map,
        'n_records': img_counter
    }
    with open(data_info_json_path, 'w') as outfile:
        json.dump(data_info, outfile)



# Output
dataset_name = "train"  # train, valid, test
tfrecord_dir_test = os.path.join(tfrecord_dir, dataset_name)
tfrecord_prefix_test = dataset_name
tfrecord_n_shards = 8

# Image List
image_path_list = image_list[512:]
print("n images = {}".format(len(image_path_list)))

image_to_tfrecord_shards(
    image_path_list=image_path_list, 
    data_meta=data_meta,
    tag_map=tag_map,
    tfrecord_dir=tfrecord_dir_test, 
    tfrecord_prefix=dataset_name, 
    n_shards=8)
# Out:
# n images = 7543
# image_path_list n = 7543
# Working on image i = 0
# Working on image i = 10
# Working on image i = 20
# Working on image i = 30
# img_id = 2652067 failed to load image ..\data\danbooru\danbooru2019\original\0067\2652067.zip
# Working on image i = 30
# Working on image i = 40
# img_id = 1619069 failed to load image ..\data\danbooru\danbooru2019\original\0069\1619069.gif
# Working on image i = 50
# Working on image i = 60
# Working on image i = 70
# Working on image i = 80
# Working on image i = 90
# Working on image i = 100
# Working on image i = 110
# Working on image i = 120
# img_id = 665081 failed to load image ..\data\danbooru\danbooru2019\original\0081\665081.gif
# Working on image i = 130
# Working on image i = 140
# Working on image i = 150
# Working on image i = 160
# Working on image i = 170
# Working on image i = 180
# Working on image i = 190
# Working on image i = 200
# Working on image i = 210
# Working on image i = 220
# Working on image i = 230
# Working on image i = 240
# Working on image i = 250
# Working on image i = 260
# Working on image i = 270
# Working on image i = 280
# img_id = 2143099 failed to load image ..\data\danbooru\danbooru2019\original\0099\2143099.webm
# Working on image i = 290
# Working on image i = 300
# Working on image i = 310
# Working on image i = 320
# Working on image i = 330
# Working on image i = 340
# Working on image i = 350
# Working on image i = 360
# Working on image i = 370
# Working on image i = 380
# Working on image i = 390
# Working on image i = 400
# Working on image i = 410
# Working on image i = 420
# Working on image i = 430
# Working on image i = 440
# Working on image i = 450
# Working on image i = 460
# Working on image i = 470
# Working on image i = 480
# img_id = 571123 failed to load image ..\data\danbooru\danbooru2019\original\0123\571123.gif
# Working on image i = 490
# img_id = 571125 failed to load image ..\data\danbooru\danbooru2019\original\0125\571125.gif
# img_id = 625125 failed to load image ..\data\danbooru\danbooru2019\original\0125\625125.gif
# Working on image i = 500
# Working on image i = 510
# Working on image i = 520
# Working on image i = 530
# Working on image i = 540
# Working on image i = 550
# img_id = 1580132 failed to load image ..\data\danbooru\danbooru2019\original\0132\1580132.gif
# Working on image i = 560
# Working on image i = 570
# Working on image i = 580
# Working on image i = 590
# Working on image i = 600
# Working on image i = 610
# img_id = 575140 failed to load image ..\data\danbooru\danbooru2019\original\0140\575140.swf
# img_id = 1331142 failed to load image ..\data\danbooru\danbooru2019\original\0142\1331142.gif
# Working on image i = 620
# Working on image i = 630
# Working on image i = 640
# Working on image i = 650
# Working on image i = 660
# Working on image i = 670
# Working on image i = 680
# Working on image i = 690
# Working on image i = 700
# Working on image i = 710
# img_id = 180155 failed to load image ..\data\danbooru\danbooru2019\original\0155\180155.swf
# Working on image i = 720
# Working on image i = 730
# img_id = 2274157 failed to load image ..\data\danbooru\danbooru2019\original\0157\2274157.gif
# Working on image i = 740
# Working on image i = 750
# img_id = 587159 failed to load image ..\data\danbooru\danbooru2019\original\0159\587159.gif
# Working on image i = 760
# img_id = 408160 failed to load image ..\data\danbooru\danbooru2019\original\0160\408160.gif
# Working on image i = 770
# Working on image i = 780
# Working on image i = 790
# Working on image i = 800
# img_id = 98166 failed to load image ..\data\danbooru\danbooru2019\original\0166\98166.swf
# img_id = 2926167 failed to load image ..\data\danbooru\danbooru2019\original\0167\2926167.mp4
# Working on image i = 810
# Working on image i = 820
# Working on image i = 830
# Working on image i = 840
# Working on image i = 850
# Working on image i = 860
# Working on image i = 870
# Working on image i = 880
# Working on image i = 890
# img_id = 1188178 failed to load image ..\data\danbooru\danbooru2019\original\0178\1188178.swf
# Working on image i = 890
# Working on image i = 900
# Working on image i = 910
# Working on image i = 920
# img_id = 3614184 failed to load image ..\data\danbooru\danbooru2019\original\0184\3614184.mp4
# Working on image i = 930
# Working on image i = 940
# img_id = 3402186 failed to load image ..\data\danbooru\danbooru2019\original\0186\3402186.gif
# Working on image i = 950
# Working on image i = 960
# Working on image i = 970
# img_id = 3402189 failed to load image ..\data\danbooru\danbooru2019\original\0189\3402189.zip
# Working on image i = 970
# Working on image i = 980
# Working on image i = 990
# Working on image i = 1000
# Working on image i = 1010
# Working on image i = 1020
# Working on image i = 1030
# Working on image i = 1040
# Working on image i = 1050
# Working on image i = 1060
# Working on image i = 1070
# img_id = 1651202 failed to load image ..\data\danbooru\danbooru2019\original\0202\1651202.gif
# Working on image i = 1070
# Working on image i = 1080
# Working on image i = 1090
# Working on image i = 1100
# Working on image i = 1110
# Working on image i = 1120
# Working on image i = 1130
# Working on image i = 1140
# Working on image i = 1150
# Working on image i = 1160
# Working on image i = 1170
# Working on image i = 1180
# Working on image i = 1190
# Working on image i = 1200
# Working on image i = 1210
# Working on image i = 1220
# img_id = 2810219 failed to load image ..\data\danbooru\danbooru2019\original\0219\2810219.gif
# Working on image i = 1230
# Working on image i = 1240
# Working on image i = 1250
# Working on image i = 1260
# Working on image i = 1270
# Working on image i = 1280
# Working on image i = 1290
# Working on image i = 1300
# Working on image i = 1310
# Working on image i = 1320
# Working on image i = 1330
# Working on image i = 1340
# img_id = 544233 failed to load image ..\data\danbooru\danbooru2019\original\0233\544233.gif
# Working on image i = 1340
# Working on image i = 1350
# Working on image i = 1360
# Working on image i = 1370
# Working on image i = 1380
# Working on image i = 1390
# Working on image i = 1400
# Working on image i = 1410
# img_id = 634242 failed to load image ..\data\danbooru\danbooru2019\original\0242\634242.gif
# img_id = 176243 failed to load image ..\data\danbooru\danbooru2019\original\0243\176243.gif
# Working on image i = 1420
# Working on image i = 1430
# Working on image i = 1440
# Working on image i = 1450
# Working on image i = 1460
# Working on image i = 1470
# img_id = 1894251 failed to load image ..\data\danbooru\danbooru2019\original\0251\1894251.gif
# Working on image i = 1480
# img_id = 2894253 failed to load image ..\data\danbooru\danbooru2019\original\0253\2894253.webm
# Working on image i = 1490
# Working on image i = 1500
# img_id = 285255 failed to load image ..\data\danbooru\danbooru2019\original\0255\285255.gif
# Working on image i = 1510
# Working on image i = 1520
# Working on image i = 1530
# Working on image i = 1540
# Working on image i = 1550
# Working on image i = 1560
# img_id = 2392264 failed to load image ..\data\danbooru\danbooru2019\original\0264\2392264.zip
# Working on image i = 1570
# Working on image i = 1580
# Working on image i = 1590
# Working on image i = 1600
# Working on image i = 1610
# Working on image i = 1620
# img_id = 40275 failed to load image ..\data\danbooru\danbooru2019\original\0275\40275.gif
# Working on image i = 1630
# Working on image i = 1640
# Working on image i = 1650
# Working on image i = 1660
# Working on image i = 1670
# Working on image i = 1680
# Working on image i = 1690
# Working on image i = 1700
# Working on image i = 1710
# Working on image i = 1720
# Working on image i = 1730
# Working on image i = 1740
# img_id = 3542290 failed to load image ..\data\danbooru\danbooru2019\original\0290\3542290.zip
# Working on image i = 1750
# Working on image i = 1760
# img_id = 322292 failed to load image ..\data\danbooru\danbooru2019\original\0292\322292.gif
# Working on image i = 1760
# Working on image i = 1770
# Working on image i = 1780
# Working on image i = 1790
# Working on image i = 1800
# Working on image i = 1810
# Working on image i = 1820
# img_id = 35298 failed to load image ..\data\danbooru\danbooru2019\original\0298\35298.gif
# Working on image i = 1820
# Working on image i = 1830
# img_id = 628299 failed to load image ..\data\danbooru\danbooru2019\original\0299\628299.gif
# Working on image i = 1830
# img_id = 566300 failed to load image ..\data\danbooru\danbooru2019\original\0300\566300.gif
# Working on image i = 1840
# Working on image i = 1850
# Working on image i = 1860
# Working on image i = 1870
# Working on image i = 1880
# Working on image i = 1890
# Working on image i = 1900
# img_id = 3119306 failed to load image ..\data\danbooru\danbooru2019\original\0306\3119306.zip
# Working on image i = 1910
# Working on image i = 1920
# Working on image i = 1930
# Working on image i = 1940
# Working on image i = 1950
# Working on image i = 1960
# img_id = 3227312 failed to load image ..\data\danbooru\danbooru2019\original\0312\3227312.zip
# Working on image i = 1970
# Working on image i = 1980
# img_id = 58314 failed to load image ..\data\danbooru\danbooru2019\original\0314\58314.gif
# Working on image i = 1990
# Working on image i = 2000
# img_id = 628316 failed to load image ..\data\danbooru\danbooru2019\original\0316\628316.gif
# img_id = 928316 failed to load image ..\data\danbooru\danbooru2019\original\0316\928316.swf
# Working on image i = 2010
# Working on image i = 2020
# Working on image i = 2030
# Working on image i = 2040
# Working on image i = 2050
# Working on image i = 2060
# Working on image i = 2070
# Working on image i = 2080
# img_id = 3321323 failed to load image ..\data\danbooru\danbooru2019\original\0323\3321323.zip
# Working on image i = 2090
# img_id = 2990324 failed to load image ..\data\danbooru\danbooru2019\original\0324\2990324.zip
# Working on image i = 2100
# Working on image i = 2110
# Working on image i = 2120
# Working on image i = 2130
# Working on image i = 2140
# img_id = 2115329 failed to load image ..\data\danbooru\danbooru2019\original\0329\2115329.zip
# Working on image i = 2150
# Working on image i = 2160
# Working on image i = 2170
# Working on image i = 2180
# Working on image i = 2190
# Working on image i = 2200
# Working on image i = 2210
# Working on image i = 2220
# Working on image i = 2230
# img_id = 883337 failed to load image ..\data\danbooru\danbooru2019\original\0337\883337.gif
# Working on image i = 2240
# Working on image i = 2250
# Working on image i = 2260
# Working on image i = 2270
# Working on image i = 2280
# Working on image i = 2290
# Working on image i = 2300
# Working on image i = 2310
# Working on image i = 2320
# Working on image i = 2330
# Working on image i = 2340
# img_id = 708349 failed to load image ..\data\danbooru\danbooru2019\original\0349\708349.swf
# Working on image i = 2350
# Working on image i = 2360
# Working on image i = 2370
# img_id = 3265352 failed to load image ..\data\danbooru\danbooru2019\original\0352\3265352.gif
# img_id = 3610353 failed to load image ..\data\danbooru\danbooru2019\original\0353\3610353.gif
# Working on image i = 2380
# Working on image i = 2390
# Working on image i = 2400
# Working on image i = 2410
# Working on image i = 2420
# img_id = 631358 failed to load image ..\data\danbooru\danbooru2019\original\0358\631358.swf
# Working on image i = 2430
# Working on image i = 2440
# Working on image i = 2450
# Working on image i = 2460
# Working on image i = 2470
# Working on image i = 2480
# Working on image i = 2490
# Working on image i = 2500
# Working on image i = 2510
# Working on image i = 2520
# img_id = 2868372 failed to load image ..\data\danbooru\danbooru2019\original\0372\2868372.gif
# Working on image i = 2530
# Working on image i = 2540
# img_id = 353374 failed to load image ..\data\danbooru\danbooru2019\original\0374\353374.gif
# Working on image i = 2550
# Working on image i = 2560
# Working on image i = 2570
# img_id = 3438377 failed to load image ..\data\danbooru\danbooru2019\original\0377\3438377.zip
# Working on image i = 2570
# Working on image i = 2580
# Working on image i = 2590
# Working on image i = 2600
# Working on image i = 2610
# img_id = 2098382 failed to load image ..\data\danbooru\danbooru2019\original\0382\2098382.zip
# Working on image i = 2620
# Working on image i = 2630
# img_id = 3082384 failed to load image ..\data\danbooru\danbooru2019\original\0384\3082384.gif
# Working on image i = 2640
# Working on image i = 2650
# Working on image i = 2660
# Working on image i = 2670
# Working on image i = 2680
# Working on image i = 2690
# Working on image i = 2700
# img_id = 481394 failed to load image ..\data\danbooru\danbooru2019\original\0394\481394.gif
# Working on image i = 2710
# Working on image i = 2720
# Working on image i = 2730
# img_id = 1990398 failed to load image ..\data\danbooru\danbooru2019\original\0398\1990398.zip
# Working on image i = 2740
# Working on image i = 2750
# Working on image i = 2760
# Working on image i = 2770
# Working on image i = 2780
# Working on image i = 2790
# Working on image i = 2800
# img_id = 476406 failed to load image ..\data\danbooru\danbooru2019\original\0406\476406.gif
# Working on image i = 2810
# Working on image i = 2820
# Working on image i = 2830
# Working on image i = 2840
# Working on image i = 2850
# Working on image i = 2860
# Working on image i = 2870
# Working on image i = 2880
# Working on image i = 2890
# Working on image i = 2900
# img_id = 565418 failed to load image ..\data\danbooru\danbooru2019\original\0418\565418.gif
# Working on image i = 2900
# Working on image i = 2910
# Working on image i = 2920
# Working on image i = 2930
# Working on image i = 2940
# Working on image i = 2950
# Working on image i = 2960
# Working on image i = 2970
# Working on image i = 2980
# img_id = 851430 failed to load image ..\data\danbooru\danbooru2019\original\0430\851430.swf
# Working on image i = 2990
# Working on image i = 3000
# Working on image i = 3010
# Working on image i = 3020
# Working on image i = 3030
# img_id = 3601439 failed to load image ..\data\danbooru\danbooru2019\original\0439\3601439.gif
# Working on image i = 3040
# img_id = 3449440 failed to load image ..\data\danbooru\danbooru2019\original\0440\3449440.zip
# Working on image i = 3050
# img_id = 2987442 failed to load image ..\data\danbooru\danbooru2019\original\0442\2987442.gif
# Working on image i = 3060
# Working on image i = 3070
# Working on image i = 3080
# Working on image i = 3090
# Working on image i = 3100
# Working on image i = 3110
# Working on image i = 3120
# Working on image i = 3130
# img_id = 3411451 failed to load image ..\data\danbooru\danbooru2019\original\0451\3411451.gif
# Working on image i = 3140
# Working on image i = 3150
# img_id = 1017454 failed to load image ..\data\danbooru\danbooru2019\original\0454\1017454.gif
# Working on image i = 3160
# Working on image i = 3170
# Working on image i = 3180
# Working on image i = 3190
# Working on image i = 3200
# Working on image i = 3210
# Working on image i = 3220
# Working on image i = 3230
# Working on image i = 3240
# Working on image i = 3250
# Working on image i = 3260
# Working on image i = 3270
# Working on image i = 3280
# img_id = 96473 failed to load image ..\data\danbooru\danbooru2019\original\0473\96473.gif
# img_id = 1116474 failed to load image ..\data\danbooru\danbooru2019\original\0474\1116474.gif
# Working on image i = 3290
# Working on image i = 3300
# Working on image i = 3310
# Working on image i = 3320
# Working on image i = 3330
# img_id = 66478 failed to load image ..\data\danbooru\danbooru2019\original\0478\66478.gif
# Working on image i = 3340
# Working on image i = 3350
# img_id = 3448480 failed to load image ..\data\danbooru\danbooru2019\original\0480\3448480.webm
# Working on image i = 3360
# Working on image i = 3370
# Working on image i = 3380
# Working on image i = 3390
# Working on image i = 3400
# Working on image i = 3410
# Working on image i = 3420
# Working on image i = 3430
# Working on image i = 3440
# Working on image i = 3450
# Working on image i = 3460
# Working on image i = 3470
# Working on image i = 3480
# img_id = 2151497 failed to load image ..\data\danbooru\danbooru2019\original\0497\2151497.webm
# Working on image i = 3480
# Working on image i = 3490
# Working on image i = 3500
# img_id = 3541499 failed to load image ..\data\danbooru\danbooru2019\original\0499\3541499.zip
# Working on image i = 3510
# Working on image i = 3520
# img_id = 2151501 failed to load image ..\data\danbooru\danbooru2019\original\0501\2151501.webm
# Working on image i = 3530
# Working on image i = 3540
# Working on image i = 3550
# Working on image i = 3560
# Working on image i = 3570
# Working on image i = 3580
# Working on image i = 3590
# Working on image i = 3600
# Working on image i = 3610
# Working on image i = 3620
# Working on image i = 3630
# Working on image i = 3640
# Working on image i = 3650
# Working on image i = 3660
# Working on image i = 3670
# Working on image i = 3680
# img_id = 47522 failed to load image ..\data\danbooru\danbooru2019\original\0522\47522.gif
# Working on image i = 3690
# Working on image i = 3700
# Working on image i = 3710
# Working on image i = 3720
# Working on image i = 3730
# Working on image i = 3740
# Working on image i = 3750
# Working on image i = 3760
# Working on image i = 3770
# Working on image i = 3780
# Working on image i = 3790
# img_id = 3623534 failed to load image ..\data\danbooru\danbooru2019\original\0534\3623534.gif
# Working on image i = 3800
# Working on image i = 3810
# img_id = 6537 failed to load image ..\data\danbooru\danbooru2019\original\0537\6537.gif
# Working on image i = 3820
# img_id = 76538 failed to load image ..\data\danbooru\danbooru2019\original\0538\76538.gif
# Working on image i = 3830
# Working on image i = 3840
# Working on image i = 3850
# Working on image i = 3860
# img_id = 639545 failed to load image ..\data\danbooru\danbooru2019\original\0545\639545.gif
# Working on image i = 3870
# img_id = 574547 failed to load image ..\data\danbooru\danbooru2019\original\0547\574547.gif
# Working on image i = 3880
# img_id = 3175550 failed to load image ..\data\danbooru\danbooru2019\original\0550\3175550.gif
# Working on image i = 3890
# img_id = 750551 failed to load image ..\data\danbooru\danbooru2019\original\0551\750551.swf
# Working on image i = 3900
# Working on image i = 3910
# Working on image i = 3920
# img_id = 3175554 failed to load image ..\data\danbooru\danbooru2019\original\0554\3175554.zip
# Working on image i = 3920
# Working on image i = 3930
# Working on image i = 3940
# Working on image i = 3950
# Working on image i = 3960
# Working on image i = 3970
# Working on image i = 3980
# img_id = 3030565 failed to load image ..\data\danbooru\danbooru2019\original\0565\3030565.gif
# img_id = 3187565 failed to load image ..\data\danbooru\danbooru2019\original\0565\3187565.gif
# Working on image i = 3990
# Working on image i = 4000
# img_id = 3030568 failed to load image ..\data\danbooru\danbooru2019\original\0568\3030568.gif
# Working on image i = 4010
# img_id = 566569 failed to load image ..\data\danbooru\danbooru2019\original\0569\566569.gif
# Working on image i = 4020
# Working on image i = 4030
# img_id = 566571 failed to load image ..\data\danbooru\danbooru2019\original\0571\566571.gif
# img_id = 3511572 failed to load image ..\data\danbooru\danbooru2019\original\0572\3511572.mp4
# Working on image i = 4040
# Working on image i = 4050
# img_id = 566573 failed to load image ..\data\danbooru\danbooru2019\original\0573\566573.gif
# Working on image i = 4050
# Working on image i = 4060
# Working on image i = 4070
# Working on image i = 4080
# Working on image i = 4090
# Working on image i = 4100
# Working on image i = 4110
# Working on image i = 4120
# Working on image i = 4130
# img_id = 566583 failed to load image ..\data\danbooru\danbooru2019\original\0583\566583.gif
# Working on image i = 4140
# Working on image i = 4150
# img_id = 402585 failed to load image ..\data\danbooru\danbooru2019\original\0585\402585.gif
# Working on image i = 4160
# img_id = 677586 failed to load image ..\data\danbooru\danbooru2019\original\0586\677586.gif
# Working on image i = 4170
# img_id = 1589 failed to load image ..\data\danbooru\danbooru2019\original\0589\1589.gif
# Working on image i = 4180
# Working on image i = 4190
# Working on image i = 4200
# Working on image i = 4210
# img_id = 1395593 failed to load image ..\data\danbooru\danbooru2019\original\0593\1395593.gif
# Working on image i = 4220
# Working on image i = 4230
# Working on image i = 4240
# Working on image i = 4250
# img_id = 2543598 failed to load image ..\data\danbooru\danbooru2019\original\0598\2543598.gif
# Working on image i = 4260
# Working on image i = 4270
# img_id = 697600 failed to load image ..\data\danbooru\danbooru2019\original\0600\697600.gif
# Working on image i = 4270
# Working on image i = 4280
# Working on image i = 4290
# Working on image i = 4300
# img_id = 108606 failed to load image ..\data\danbooru\danbooru2019\original\0606\108606.gif
# Working on image i = 4310
# Working on image i = 4320
# Working on image i = 4330
# Working on image i = 4340
# img_id = 2144610 failed to load image ..\data\danbooru\danbooru2019\original\0610\2144610.zip
# Working on image i = 4350
# Working on image i = 4360
# Working on image i = 4370
# Working on image i = 4380
# Working on image i = 4390
# img_id = 1514617 failed to load image ..\data\danbooru\danbooru2019\original\0617\1514617.gif
# Working on image i = 4400
# Working on image i = 4410
# Working on image i = 4420
# Working on image i = 4430
# Working on image i = 4440
# Working on image i = 4450
# Working on image i = 4460
# Working on image i = 4470
# Working on image i = 4480
# Working on image i = 4490
# Working on image i = 4500
# img_id = 2854630 failed to load image ..\data\danbooru\danbooru2019\original\0630\2854630.gif
# Working on image i = 4510
# Working on image i = 4520
# img_id = 32633 failed to load image ..\data\danbooru\danbooru2019\original\0633\32633.gif
# Working on image i = 4530
# Working on image i = 4540
# Working on image i = 4550
# Working on image i = 4560
# Working on image i = 4570
# img_id = 2026638 failed to load image ..\data\danbooru\danbooru2019\original\0638\2026638.zip
# img_id = 2650639 failed to load image ..\data\danbooru\danbooru2019\original\0639\2650639.zip
# Working on image i = 4580
# Working on image i = 4590
# img_id = 83640 failed to load image ..\data\danbooru\danbooru2019\original\0640\83640.gif
# Working on image i = 4600
# Working on image i = 4610
# Working on image i = 4620
# Working on image i = 4630
# img_id = 9645 failed to load image ..\data\danbooru\danbooru2019\original\0645\9645.gif
# Working on image i = 4640
# Working on image i = 4650
# img_id = 3031649 failed to load image ..\data\danbooru\danbooru2019\original\0649\3031649.gif
# Working on image i = 4660
# Working on image i = 4670
# Working on image i = 4680
# img_id = 605653 failed to load image ..\data\danbooru\danbooru2019\original\0653\605653.gif
# Working on image i = 4690
# Working on image i = 4700
# Working on image i = 4710
# img_id = 587656 failed to load image ..\data\danbooru\danbooru2019\original\0656\587656.gif
# Working on image i = 4710
# img_id = 3486657 failed to load image ..\data\danbooru\danbooru2019\original\0657\3486657.gif
# Working on image i = 4720
# Working on image i = 4730
# Working on image i = 4740
# Working on image i = 4750
# Working on image i = 4760
# img_id = 356664 failed to load image ..\data\danbooru\danbooru2019\original\0664\356664.gif
# Working on image i = 4770
# Working on image i = 4780
# Working on image i = 4790
# Working on image i = 4800
# img_id = 3362670 failed to load image ..\data\danbooru\danbooru2019\original\0670\3362670.mp4
# Working on image i = 4810
# Working on image i = 4820
# img_id = 603672 failed to load image ..\data\danbooru\danbooru2019\original\0672\603672.gif
# img_id = 2363673 failed to load image ..\data\danbooru\danbooru2019\original\0673\2363673.zip
# Working on image i = 4830
# img_id = 1065675 failed to load image ..\data\danbooru\danbooru2019\original\0675\1065675.gif
# Working on image i = 4840
# Working on image i = 4850
# Working on image i = 4860
# Working on image i = 4870
# img_id = 1426680 failed to load image ..\data\danbooru\danbooru2019\original\0680\1426680.gif
# Working on image i = 4880
# Working on image i = 4890
# Working on image i = 4900
# Working on image i = 4910
# Working on image i = 4920
# Working on image i = 4930
# Working on image i = 4940
# img_id = 429690 failed to load image ..\data\danbooru\danbooru2019\original\0690\429690.swf
# Working on image i = 4950
# Working on image i = 4960
# Working on image i = 4970
# Working on image i = 4980
# Working on image i = 4990
# Working on image i = 5000
# Working on image i = 5010
# Working on image i = 5020
# img_id = 36699 failed to load image ..\data\danbooru\danbooru2019\original\0699\36699.swf
# Working on image i = 5020
# Working on image i = 5030
# Working on image i = 5040
# Working on image i = 5050
# Working on image i = 5060
# Working on image i = 5070
# Working on image i = 5080
# img_id = 3071709 failed to load image ..\data\danbooru\danbooru2019\original\0709\3071709.mp4
# Working on image i = 5090
# Working on image i = 5100
# Working on image i = 5110
# Working on image i = 5120
# Working on image i = 5130
# Working on image i = 5140
# img_id = 1609717 failed to load image ..\data\danbooru\danbooru2019\original\0717\1609717.gif
# Working on image i = 5150
# img_id = 2837719 failed to load image ..\data\danbooru\danbooru2019\original\0719\2837719.gif
# Working on image i = 5160
# Working on image i = 5170
# Working on image i = 5180
# img_id = 1302723 failed to load image ..\data\danbooru\danbooru2019\original\0723\1302723.gif
# Working on image i = 5190
# Working on image i = 5200
# Working on image i = 5210
# Working on image i = 5220
# img_id = 418726 failed to load image ..\data\danbooru\danbooru2019\original\0726\418726.gif
# Working on image i = 5230
# Working on image i = 5240
# Working on image i = 5250
# Working on image i = 5260
# img_id = 625732 failed to load image ..\data\danbooru\danbooru2019\original\0732\625732.gif
# Working on image i = 5270
# Working on image i = 5280
# Working on image i = 5290
# Working on image i = 5300
# Working on image i = 5310
# Working on image i = 5320
# img_id = 3114744 failed to load image ..\data\danbooru\danbooru2019\original\0744\3114744.gif
# Working on image i = 5330
# Working on image i = 5340
# Working on image i = 5350
# Working on image i = 5360
# Working on image i = 5370
# img_id = 377750 failed to load image ..\data\danbooru\danbooru2019\original\0750\377750.swf
# Working on image i = 5370
# img_id = 3070751 failed to load image ..\data\danbooru\danbooru2019\original\0751\3070751.gif
# Working on image i = 5380
# img_id = 3118753 failed to load image ..\data\danbooru\danbooru2019\original\0753\3118753.gif
# Working on image i = 5390
# Working on image i = 5400
# Working on image i = 5410
# img_id = 3118757 failed to load image ..\data\danbooru\danbooru2019\original\0757\3118757.gif
# Working on image i = 5420
# Working on image i = 5430
# img_id = 2291760 failed to load image ..\data\danbooru\danbooru2019\original\0760\2291760.mp4
# img_id = 3038760 failed to load image ..\data\danbooru\danbooru2019\original\0760\3038760.gif
# Working on image i = 5440
# Working on image i = 5450
# Working on image i = 5460
# img_id = 626763 failed to load image ..\data\danbooru\danbooru2019\original\0763\626763.gif
# Working on image i = 5470
# img_id = 3339766 failed to load image ..\data\danbooru\danbooru2019\original\0766\3339766.mp4
# Working on image i = 5480
# img_id = 3118768 failed to load image ..\data\danbooru\danbooru2019\original\0768\3118768.gif
# Working on image i = 5490
# Working on image i = 5500
# img_id = 1617773 failed to load image ..\data\danbooru\danbooru2019\original\0773\1617773.gif
# Working on image i = 5510
# Working on image i = 5520
# Working on image i = 5530
# Working on image i = 5540
# Working on image i = 5550
# Working on image i = 5560
# Working on image i = 5570
# Working on image i = 5580
# Working on image i = 5590
# Working on image i = 5600
# Working on image i = 5610
# Working on image i = 5620
# img_id = 3214789 failed to load image ..\data\danbooru\danbooru2019\original\0789\3214789.zip
# Working on image i = 5630
# Working on image i = 5640
# Working on image i = 5650
# Working on image i = 5660
# Working on image i = 5670
# Working on image i = 5680
# img_id = 1361794 failed to load image ..\data\danbooru\danbooru2019\original\0794\1361794.gif
# Working on image i = 5680
# Working on image i = 5690
# Working on image i = 5700
# img_id = 3134796 failed to load image ..\data\danbooru\danbooru2019\original\0796\3134796.gif
# img_id = 3556796 failed to load image ..\data\danbooru\danbooru2019\original\0796\3556796.gif
# Working on image i = 5710
# Working on image i = 5720
# Working on image i = 5730
# Working on image i = 5740
# Working on image i = 5750
# Working on image i = 5760
# Working on image i = 5770
# Working on image i = 5780
# img_id = 3006806 failed to load image ..\data\danbooru\danbooru2019\original\0806\3006806.mp4
# Working on image i = 5790
# Working on image i = 5800
# Working on image i = 5810
# Working on image i = 5820
# Working on image i = 5830
# Working on image i = 5840
# Working on image i = 5850
# Working on image i = 5860
# Working on image i = 5870
# Working on image i = 5880
# img_id = 115817 failed to load image ..\data\danbooru\danbooru2019\original\0817\115817.gif
# Working on image i = 5890
# Working on image i = 5900
# Working on image i = 5910
# Working on image i = 5920
# img_id = 566821 failed to load image ..\data\danbooru\danbooru2019\original\0821\566821.gif
# Working on image i = 5930
# img_id = 1841822 failed to load image ..\data\danbooru\danbooru2019\original\0822\1841822.swf
# Working on image i = 5930
# Working on image i = 5940
# img_id = 3573823 failed to load image ..\data\danbooru\danbooru2019\original\0823\3573823.mp4
# Working on image i = 5950
# Working on image i = 5960
# Working on image i = 5970
# Working on image i = 5980
# Working on image i = 5990
# Working on image i = 6000
# Working on image i = 6010
# Working on image i = 6020
# Working on image i = 6030
# img_id = 3038834 failed to load image ..\data\danbooru\danbooru2019\original\0834\3038834.gif
# Working on image i = 6030
# Working on image i = 6040
# Working on image i = 6050
# img_id = 655836 failed to load image ..\data\danbooru\danbooru2019\original\0836\655836.gif
# Working on image i = 6060
# img_id = 3387838 failed to load image ..\data\danbooru\danbooru2019\original\0838\3387838.gif
# Working on image i = 6070
# img_id = 651840 failed to load image ..\data\danbooru\danbooru2019\original\0840\651840.swf
# Working on image i = 6080
# img_id = 623841 failed to load image ..\data\danbooru\danbooru2019\original\0841\623841.gif
# Working on image i = 6090
# Working on image i = 6100
# Working on image i = 6110
# Working on image i = 6120
# img_id = 654848 failed to load image ..\data\danbooru\danbooru2019\original\0848\654848.gif
# Working on image i = 6130
# Working on image i = 6140
# Working on image i = 6150
# Working on image i = 6160
# Working on image i = 6170
# Working on image i = 6180
# Working on image i = 6190
# Working on image i = 6200
# Working on image i = 6210
# Working on image i = 6220
# Working on image i = 6230
# Working on image i = 6240
# Working on image i = 6250
# Working on image i = 6260
# Working on image i = 6270
# img_id = 1714868 failed to load image ..\data\danbooru\danbooru2019\original\0868\1714868.gif
# Working on image i = 6270
# img_id = 1073869 failed to load image ..\data\danbooru\danbooru2019\original\0869\1073869.swf
# Working on image i = 6280
# Working on image i = 6290
# img_id = 2894870 failed to load image ..\data\danbooru\danbooru2019\original\0870\2894870.gif
# Working on image i = 6290
# Working on image i = 6300
# Working on image i = 6310
# Working on image i = 6320
# Working on image i = 6330
# Working on image i = 6340
# Working on image i = 6350
# Working on image i = 6360
# Working on image i = 6370
# img_id = 1098880 failed to load image ..\data\danbooru\danbooru2019\original\0880\1098880.gif
# Working on image i = 6380
# Working on image i = 6390
# Working on image i = 6400
# Working on image i = 6410
# Working on image i = 6420
# Working on image i = 6430
# img_id = 1930886 failed to load image ..\data\danbooru\danbooru2019\original\0886\1930886.gif
# Working on image i = 6440
# img_id = 3699886 failed to load image ..\data\danbooru\danbooru2019\original\0886\3699886.mp4
# Working on image i = 6450
# img_id = 14888 failed to load image ..\data\danbooru\danbooru2019\original\0888\14888.gif
# Working on image i = 6460
# img_id = 3356889 failed to load image ..\data\danbooru\danbooru2019\original\0889\3356889.mp4
# Working on image i = 6470
# Working on image i = 6480
# img_id = 740891 failed to load image ..\data\danbooru\danbooru2019\original\0891\740891.gif
# Working on image i = 6490
# img_id = 549892 failed to load image ..\data\danbooru\danbooru2019\original\0892\549892.gif
# Working on image i = 6500
# Working on image i = 6510
# Working on image i = 6520
# Working on image i = 6530
# Working on image i = 6540
# Working on image i = 6550
# Working on image i = 6560
# Working on image i = 6570
# img_id = 1023902 failed to load image ..\data\danbooru\danbooru2019\original\0902\1023902.swf
# Working on image i = 6580
# Working on image i = 6590
# Working on image i = 6600
# Working on image i = 6610
# img_id = 2357905 failed to load image ..\data\danbooru\danbooru2019\original\0905\2357905.gif
# Working on image i = 6620
# Working on image i = 6630
# img_id = 2357907 failed to load image ..\data\danbooru\danbooru2019\original\0907\2357907.gif
# img_id = 2357908 failed to load image ..\data\danbooru\danbooru2019\original\0908\2357908.gif
# Working on image i = 6640
# Working on image i = 6650
# Working on image i = 6660
# Working on image i = 6670
# Working on image i = 6680
# Working on image i = 6690
# Working on image i = 6700
# Working on image i = 6710
# Working on image i = 6720
# Working on image i = 6730
# Working on image i = 6740
# Working on image i = 6750
# Working on image i = 6760
# Working on image i = 6770
# Working on image i = 6780
# Working on image i = 6790
# Working on image i = 6800
# Working on image i = 6810
# Working on image i = 6820
# Working on image i = 6830
# Working on image i = 6840
# Working on image i = 6850
# Working on image i = 6860
# Working on image i = 6870
# Working on image i = 6880
# Working on image i = 6890
# img_id = 3194938 failed to load image ..\data\danbooru\danbooru2019\original\0938\3194938.zip
# Working on image i = 6900
# Working on image i = 6910
# Working on image i = 6920
# img_id = 3298942 failed to load image ..\data\danbooru\danbooru2019\original\0942\3298942.mp4
# img_id = 3396942 failed to load image ..\data\danbooru\danbooru2019\original\0942\3396942.mp4
# Working on image i = 6930
# Working on image i = 6940
# Working on image i = 6950
# Working on image i = 6960
# img_id = 2892949 failed to load image ..\data\danbooru\danbooru2019\original\0949\2892949.gif
# Working on image i = 6970
# Working on image i = 6980
# Working on image i = 6990
# img_id = 646952 failed to load image ..\data\danbooru\danbooru2019\original\0952\646952.gif
# Working on image i = 7000
# img_id = 3072954 failed to load image ..\data\danbooru\danbooru2019\original\0954\3072954.mp4
# Working on image i = 7010
# img_id = 2222956 failed to load image ..\data\danbooru\danbooru2019\original\0956\2222956.zip
# Working on image i = 7020
# Working on image i = 7030
# Working on image i = 7040
# Working on image i = 7050
# img_id = 47961 not in data_met
# img_id = 2134962 failed to load image ..\data\danbooru\danbooru2019\original\0962\2134962.zip
# Working on image i = 7060
# Working on image i = 7070
# Working on image i = 7080
# Working on image i = 7090
# img_id = 1036967 failed to load image ..\data\danbooru\danbooru2019\original\0967\1036967.swf
# Working on image i = 7100
# Working on image i = 7110
# Working on image i = 7120
# Working on image i = 7130
# Working on image i = 7140
# Working on image i = 7150
# Working on image i = 7160
# Working on image i = 7170
# Working on image i = 7180
# Working on image i = 7190
# Working on image i = 7200
# Working on image i = 7210
# Working on image i = 7220
# img_id = 623981 failed to load image ..\data\danbooru\danbooru2019\original\0981\623981.gif
# Working on image i = 7230
# Working on image i = 7240
# img_id = 623984 failed to load image ..\data\danbooru\danbooru2019\original\0984\623984.gif
# Working on image i = 7250
# Working on image i = 7260
# img_id = 390986 failed to load image ..\data\danbooru\danbooru2019\original\0986\390986.gif
# Working on image i = 7260
# Working on image i = 7270
# Working on image i = 7280
# Working on image i = 7290
# Working on image i = 7300
# Working on image i = 7310
# img_id = 2986994 failed to load image ..\data\danbooru\danbooru2019\original\0994\2986994.zip
# Working on image i = 7320
# Working on image i = 7330
# Working on image i = 7340
# img_id = 619997 failed to load image ..\data\danbooru\danbooru2019\original\0997\619997.gif
# Working on image i = 7350
# img_id = 3398998 failed to load image ..\data\danbooru\danbooru2019\original\0998\3398998.gif
# Working on image i = 7360
# Made tfrecord with n = 7367
